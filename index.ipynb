# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
#Your code here
c.execute("""SELECT firstName, lastName FROM employees 
                JOIN offices USING(officeCode)
                WHERE city IS 'Boston'""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
c.execute("""SELECT COUNT(employeeNumber) FROM offices
                LEFT JOIN employees USING(officeCode)
                GROUP BY officeCode""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    COUNT(employeeNumber)
# 0                      6
# 1                      2
# 2                      2
# 3                      5
# 4                      2
# 5                      4
# 6                      2

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary
# 1. how many customers does each office serve?

# %%
# Your code here
c.execute("""SELECT officeCode, o.city, COUNT(customerNumber) as customers FROM offices o
                JOIN employees e USING(officeCode)
                JOIN customers c ON e.employeeNumber = c.salesRepEmployeeNumber
                GROUP BY officeCode""")

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   officeCode           city  customers
# 0          1  San Francisco         12
# 1          2         Boston         12
# 2          3            NYC         15
# 3          4          Paris         29
# 4          5          Tokyo          5
# 5          6         Sydney         10
# 6          7         London         17

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here
# join employees with customers, orders, orderdetails, and products
c.execute("""SELECT e.firstName, e.lastName, p.productName, FROM employees e
                JOIN customers c ON e.employeeNumber = c.salesRepEmployeeNumber
                JOIN orders o ON c.customerNumber = o.customerNumber
                JOIN orderdetails od ON o.orderNumber = od.orderNumber
                JOIN products p ON od.productCode = p.productCode
                GROUP BY p.productCode""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     firstName lastName                                  productName  \
# 0       Peter    Marsh        1969 Harley Davidson Ultimate Chopper
# 1      Martin   Gerard                     1952 Alpine Renault 1300
# 2        Mami    Nishi                        1996 Moto Guzzi 1100i
# 3        Mami    Nishi         2003 Harley-Davidson Eagle Drag Bike
# 4      Martin   Gerard                          1972 Alfa Romeo GTA
# 5      Martin   Gerard                       1962 LanciaA Delta 16V
# 6      Martin   Gerard                            1968 Ford Mustang
# 7      Martin   Gerard                            2001 Ferrari Enzo
# 8      Martin   Gerard                               1958 Setra Bus
# 9       Peter    Marsh                             2002 Suzuki XREO
# 10     Martin   Gerard                           1969 Corvair Monza
# 11     Martin   Gerard                           1968 Dodge Charger
# 12     Martin   Gerard                             1969 Ford Falcon
# 13     Martin   Gerard                      1970 Plymouth Hemi Cuda
# 14     Martin   Gerard                            1957 Chevy Pickup
# 15     Martin   Gerard                           1969 Dodge Charger
# 16     Martin   Gerard                       1940 Ford Pickup Truck
# 17     Martin   Gerard                              1993 Mazda RX-7
# 18      Peter    Marsh                         1937 Lincoln Berline
# 19     Martin   Gerard     1936 Mercedes-Benz 500K Special Roadster
# 20      Peter    Marsh                        1965 Aston Martin DB5
# 21       Mami    Nishi                  1980s Black Hawk Helicopter
# 22     Martin   Gerard                     1917 Grand Touring Sedan
# 23     Martin   Gerard                  1948 Porsche 356-A Roadster
# 24     Martin   Gerard                             1995 Honda Civic
# 25     Martin   Gerard               1998 Chrysler Plymouth Prowler
# 26     Martin   Gerard                           1911 Ford Town Car
# 27     Martin   Gerard                       1964 Mercedes Tour Bus
# 28     Martin   Gerard                    1932 Model A Ford J-Coupe
# 29     Martin   Gerard                        1926 Ford Fire Engine
# ..        ...      ...                                          ...
# 79     Martin   Gerard            1992 Porsche Cayenne Turbo Silver
# 80     Martin   Gerard                        1936 Chrysler Airflow
# 81     Martin   Gerard                      1900s Vintage Tri-Plane
# 82     Martin   Gerard                        1961 Chevrolet Impala
# 83     Martin   Gerard                  1980’s GM Manhattan Express
# 84     Martin   Gerard                             1997 BMW F650 ST
# 85       Mami    Nishi                            1982 Ducati 996 R
# 86     Martin   Gerard                  1954 Greyhound Scenicruiser
# 87     Martin   Gerard       1950's Chicago Surface Lines Streetcar
# 88     Martin   Gerard  1996 Peterbilt 379 Stake Bed with Outrigger
# 89     Martin   Gerard                     1928 Ford Phaeton Deluxe
# 90       Mami    Nishi                    1974 Ducati 350 Mk3 Desmo
# 91     Martin   Gerard                 1930 Buick Marquette Phaeton
# 92     Martin   Gerard             Diamond T620 Semi-Skirted Tanker
# 93       Mami    Nishi               1962 City of Detroit Streetcar
# 94       Mami    Nishi                           2002 Yamaha YZR M1
# 95     Martin   Gerard                        The Schooner Bluenose
# 96     Martin   Gerard                  American Airlines: B767-300
# 97     Martin   Gerard                                The Mayflower
# 98     Martin   Gerard                                   HMS Bounty
# 99     Martin   Gerard               America West Airlines B757-200
# 100    Martin   Gerard                    The USS Constitution Ship
# 101    Martin   Gerard                              1982 Camaro Z28
# 102    Martin   Gerard                                ATA: B757-300
# 103      Mami    Nishi                           F/A 18 Hornet 1/72
# 104    Martin   Gerard                                  The Titanic
# 105    Martin   Gerard                               The Queen Mary
# 106      Mami    Nishi                    American Airlines: MD-11S
# 107    Martin   Gerard                             Boeing X-32A JSF
# 108    Martin   Gerard                                   Pont Yacht
#
#      COUNT(p.productCode)
# 0                      28
# 1                      28
# 2                      28
# 3                      28
# 4                      28
# 5                      28
# 6                      27
# 7                      27
# 8                      28
# 9                      28
# 10                     27
# 11                     27
# 12                     27
# 13                     27
# 14                     28
# 15                     27
# 16                     28
# 17                     27
# 18                     28
# 19                     28
# 20                     25
# 21                     28
# 22                     25
# 23                     27
# 24                     27
# 25                     28
# 26                     25
# 27                     28
# 28                     28
# 29                     28
# ..                    ...
# 79                     27
# 80                     28
# 81                     28
# 82                     27
# 83                     28
# 84                     28
# 85                     27
# 86                     28
# 87                     27
# 88                     28
# 89                     28
# 90                     27
# 91                     28
# 92                     28
# 93                     27
# 94                     27
# 95                     27
# 96                     28
# 97                     27
# 98                     28
# 99                     28
# 100                    27
# 101                    28
# 102                    28
# 103                    28
# 104                    27
# 105                    27
# 106                    28
# 107                    28
# 108                    27
#
# [109 rows x 4 columns]

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here
c.execute("""SELECT e.firstName, e.lastName, COUNT(p.productCode) as productsSold FROM employees e
                JOIN customers c ON e.employeeNumber = c.salesRepEmployeeNumber
                JOIN orders o ON c.customerNumber = o.customerNumber
                JOIN orderdetails od ON o.orderNumber = od.orderNumber
                JOIN products p ON od.productCode = p.productCode
                GROUP BY employeeNumber""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName  productsSold
# 0     Leslie   Jennings           331
# 1     Leslie   Thompson           114
# 2      Julie   Firrelli           124
# 3      Steve  Patterson           152
# 4   Foon Yue      Tseng           142
# 5     George     Vanauf           211
# 6       Loui     Bondur           177
# 7     Gerard  Hernandez           396
# 8     Pamela   Castillo           272
# 9      Larry       Bott           236
# 10     Barry      Jones           220
# 11      Andy     Fixter           185
# 12     Peter      Marsh           185
# 13      Mami      Nishi           137
# 14    Martin     Gerard           114

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
